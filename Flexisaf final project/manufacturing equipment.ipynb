# %% [markdown]
# # Manufacturing Equipment Maintenace Prediction

# %%
# !pip install tensorflow
# importing the necessary library and dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#modelling
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU, PReLU, ELU, ReLU
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import BinaryAccuracy, Precision, Recall
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras import backend as K
from sklearn.metrics import confusion_matrix

#feature enginering
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
# Out:
# WARNING: Ignoring invalid distribution ~andas (C:\Users\uers\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\uers\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\uers\anaconda3\Lib\site-packages)
# Requirement already satisfied: tensorflow in c:\users\uers\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\uers\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\uers\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\uers\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\uers\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\uers\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uers\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uers\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uers\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uers\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\uers\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\uers\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\uers\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\uers\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\uers\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\uers\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\uers\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)

# %% [markdown]
# ### Loading the dataset

# %%
df = pd.read_csv('Dataset.csv')
df
# Out:
#         Equipment_ID  Temperature  Pressure  Vibration  Humidity  Flow_Rate  \
# 0              77546        80.03     34.84       1.59      0.50      10.91
# 1             529399        90.39     32.63       1.29      0.43      10.20
# 2             194027        93.52     37.43       1.84      0.41      10.61
# 3             588205        91.57     35.36       1.44      0.29      10.59
# 4             354137        82.37     31.54       1.66      0.48      10.40
# ...              ...          ...       ...        ...       ...        ...
# 127635         22959        90.90     35.52       1.27      0.34       9.52
# 127636        259803        99.93     39.77       1.98      0.28      11.16
# 127637        809374       103.23     39.56       1.93      0.39      11.80
# 127638        507580        81.36     36.65       1.95      0.50       9.04
# 127639        753216        75.69     30.26       1.33      0.57       8.90
#
#         Power_Consumption  Oil_Level  Voltage Maintenance_Type  \
# 0                  298.67       0.34   216.01       Preventive
# 1                  300.22       0.41   220.97       Preventive
# 2                  315.68       0.48   232.13       Corrective
# 3                  296.97       0.55   217.34       Preventive
# 4                  339.35       0.56   216.79       Preventive
# ...                   ...        ...      ...              ...
# 127635             309.04       0.60   228.05       Corrective
# 127636             285.89       0.54   229.97       Preventive
# 127637             273.59       0.60   220.25       Corrective
# 127638             267.20       0.58   212.01       Preventive
# 127639             297.35       0.55   213.33       Corrective
#
#              Failure_Cause  Maintenance_Cost  Production_Volume  \
# 0       Electrical Failure            579.69                196
# 1       Electrical Failure            647.95                291
# 2       Electrical Failure            664.85                308
# 3       Mechanical Failure            582.15                328
# 4       Electrical Failure            715.05                234
# ...                    ...               ...                ...
# 127635  Mechanical Failure            623.37                280
# 127636  Electrical Failure            487.98                280
# 127637  Electrical Failure            488.85                314
# 127638  Mechanical Failure            489.96                242
# 127639  Electrical Failure            449.68                245
#
#         Planned_Downtime_Hours  Shifts_Per_Day  Production_Days_Per_Week  \
# 0                            4               2                         6
# 1                            2               2                         6
# 2                            4               1                         5
# 3                            4               3                         5
# 4                            4               2                         5
# ...                        ...             ...                       ...
# 127635                       5               1                         5
# 127636                       5               2                         5
# 127637                       3               2                         5
# 127638                       4               2                         5
# 127639                       4               2                         5
#
#        Installation_Date Failure_Date Maintenance_Date
# 0             2020-10-25   2021-08-16       2021-08-29
# 1             2019-12-16   2021-04-06       2021-04-19
# 2             2020-05-03   2021-05-14       2021-05-27
# 3             2020-04-17   2021-07-11       2021-07-24
# 4             2020-08-16   2021-03-02       2021-03-15
# ...                  ...          ...              ...
# 127635        2020-04-26   2021-08-08       2021-08-21
# 127636        2019-08-09   2020-07-15       2020-07-28
# 127637        2019-04-06   2020-08-13       2020-08-26
# 127638        2020-06-02   2021-02-26       2021-03-11
# 127639        2019-06-18   2020-05-23       2020-06-05
#
# [127640 rows x 19 columns]

# %% [markdown]
# ### Data cleaning

# %%
df1=df.drop(columns=['Equipment_ID'], axis=1)

# %%
df1.isnull().sum()
# Out:
# Temperature                 0
# Pressure                    0
# Vibration                   0
# Humidity                    0
# Flow_Rate                   0
# Power_Consumption           0
# Oil_Level                   0
# Voltage                     0
# Maintenance_Type            0
# Failure_Cause               0
# Maintenance_Cost            0
# Production_Volume           0
# Planned_Downtime_Hours      0
# Shifts_Per_Day              0
# Production_Days_Per_Week    0
# Installation_Date           0
# Failure_Date                0
# Maintenance_Date            0
# dtype: int64

# %% [markdown]
# ### Checking for multicollinearity

# %%
#correlation heatmap
numeric_data = df1.select_dtypes(include=['number'])
plt.figure(figsize=(12,8))
sns.heatmap(numeric_data.corr(), annot=True, cmap = 'Greens')
plt.title("Correlation heat map of manufacturing equipment")
plt.show()

# %% [markdown]
# ### Removing outliers

# %%
Q1 = df1['Power_Consumption'].quantile(0.25)
Q3 = df1['Power_Consumption'].quantile(0.75)
IQR= Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
data_no_outliers_1 = (df1[(df1['Power_Consumption']>= lower_bound) & (df1['Power_Consumption']<= upper_bound)])
print("Original data shape ;", df1.shape)
print("New data without outliers ;", data_no_outliers_1.shape)
# Out:
# Original data shape ; (127640, 18)
# New data without outliers ; (126746, 18)

# %%
df1=data_no_outliers_1

# %%
df1.shape
# Out:
# (126746, 18)

# %%
x = df1.drop(columns=['Failure_Cause'], axis=1)
y = df1['Failure_Cause']

# %%
x.columns.tolist()
# Out:
# ['Temperature',
#  'Pressure',
#  'Vibration',
#  'Humidity',
#  'Flow_Rate',
#  'Power_Consumption',
#  'Oil_Level',
#  'Voltage',
#  'Maintenance_Type',
#  'Maintenance_Cost',
#  'Production_Volume',
#  'Planned_Downtime_Hours',
#  'Shifts_Per_Day',
#  'Production_Days_Per_Week',
#  'Installation_Date',
#  'Failure_Date',
#  'Maintenance_Date']

# %%
y.value_counts()
# Out:
# Failure_Cause
# Electrical Failure    84365
# Mechanical Failure    37892
# Sensor Malfunction     4489
# Name: count, dtype: int64

# %% [markdown]
# ### Feature engineering

# %%
# creating column transformer
num_features = x.select_dtypes(exclude="object").columns
cat_features = x.select_dtypes(include="object").columns

numerical_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

preprocessor = ColumnTransformer(
    [
      ("OneHotEncoder", categorical_transformer, cat_features),
      ("StandardScaler", numerical_transformer, num_features)  
    ]
)

# %% [markdown]
# ### Splitting dataset for model training purposes

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train.shape, x_test.shape
# Out:
# ((101396, 17), (25350, 17))

# %%
preprocessor.fit(x_train)
x_train_processed = preprocessor.transform(x_train)
x_test_processed = preprocessor.transform(x_test)
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# %% [markdown]
# ### Initializing the ANN model

# %%
# inititalizing ANN
classifier = Sequential()

# %%
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=35,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %% [markdown]
# ### Model building

# %%
#model building
def focal_loss(gamma=2., alpha=.25):
    
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.int32)
        num_classes = K.int_shape(y_pred)[-1]
        y_true_one_hot = tf.one_hot(y_true, depth=num_classes)
        y_pred = K.clip(y_pred, K.epsilon(), 1.0 - K.epsilon())
        cross_entropy = -y_true_one_hot * K.log(y_pred)
        loss_weight = y_true_one_hot * K.pow(1 - y_pred, gamma)
        if alpha is not None:
            alpha_factor = K.ones_like(y_true_one_hot) * alpha
            loss_weight *= alpha_factor
        loss = loss_weight * cross_entropy
        return K.sum(loss, axis=-1)
    return focal_loss_fixed

# --- Define the Model Architecture ---
def create_lean_model(num_features, num_classes):
    classifier = Sequential()
    classifier.add(layers.Dense(units=8, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)))
    classifier.add(layers.Dropout(0.3))
    classifier.add(layers.Dense(units=num_classes, activation='softmax'))
    classifier.compile(optimizer='adam', loss=focal_loss(gamma=2.0, alpha=0.25), metrics=['accuracy'])
    return classifier


NUM_FEATURES = 17
NUM_CLASSES = 3

classifier = create_lean_model(NUM_FEATURES, NUM_CLASSES)

model_history = classifier.fit(
    x_train_processed,
    y_train_encoded,
    validation_split=0.33,
    batch_size=32,
    epochs=1000,
    callbacks=early_stopping
)
# Out:
# Epoch 1/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.7367 - loss: 0.0592 - val_accuracy: 0.7977 - val_loss: 0.0351
# Epoch 2/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7797 - loss: 0.0385 - val_accuracy: 0.7991 - val_loss: 0.0345
# Epoch 3/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7830 - loss: 0.0371 - val_accuracy: 0.7984 - val_loss: 0.0342
# Epoch 4/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7849 - loss: 0.0369 - val_accuracy: 0.7998 - val_loss: 0.0339
# Epoch 5/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7820 - loss: 0.0372 - val_accuracy: 0.8005 - val_loss: 0.0337
# Epoch 6/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.7841 - loss: 0.0367 - val_accuracy: 0.8017 - val_loss: 0.0339
# Epoch 7/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.7865 - loss: 0.0363 - val_accuracy: 0.7979 - val_loss: 0.0340
# Epoch 8/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.7834 - loss: 0.0365 - val_accuracy: 0.7995 - val_loss: 0.0339
# Epoch 9/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - accuracy: 0.7795 - loss: 0.0368 - val_accuracy: 0.7994 - val_loss: 0.0340
# Epoch 10/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - accuracy: 0.7870 - loss: 0.0361 - val_accuracy: 0.7997 - val_loss: 0.0338
# Epoch 11/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.7834 - loss: 0.0367 - val_accuracy: 0.7979 - val_loss: 0.0341
# Epoch 12/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.7823 - loss: 0.0365 - val_accuracy: 0.7999 - val_loss: 0.0335
# Epoch 13/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.7868 - loss: 0.0361 - val_accuracy: 0.8000 - val_loss: 0.0335
# Epoch 14/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7807 - loss: 0.0368 - val_accuracy: 0.7991 - val_loss: 0.0336
# Epoch 15/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.7832 - loss: 0.0364 - val_accuracy: 0.7995 - val_loss: 0.0338
# Epoch 16/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.7851 - loss: 0.0363 - val_accuracy: 0.8005 - val_loss: 0.0337
# Epoch 17/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7832 - loss: 0.0363 - val_accuracy: 0.8016 - val_loss: 0.0336
# Epoch 18/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7836 - loss: 0.0359 - val_accuracy: 0.7993 - val_loss: 0.0337
# Epoch 19/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.7799 - loss: 0.0364 - val_accuracy: 0.8001 - val_loss: 0.0336
# Epoch 20/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - accuracy: 0.7855 - loss: 0.0362 - val_accuracy: 0.8005 - val_loss: 0.0337
# Epoch 21/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7826 - loss: 0.0363 - val_accuracy: 0.8005 - val_loss: 0.0335
# Epoch 22/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.7788 - loss: 0.0365 - val_accuracy: 0.7995 - val_loss: 0.0338
# Epoch 23/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.7846 - loss: 0.0361 - val_accuracy: 0.7990 - val_loss: 0.0337
# Epoch 24/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.
1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7830 - loss: 0.0361 - val_accuracy: 0.8026 - val_loss: 0.0335
# Epoch 90/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7831 - loss: 0.0363 - val_accuracy: 0.7993 - val_loss: 0.0336
# Epoch 91/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7810 - loss: 0.0362 - val_accuracy: 0.7980 - val_loss: 0.0336
# Epoch 92/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7809 - loss: 0.0363 - val_accuracy: 0.7993 - val_loss: 0.0337
# Epoch 93/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7839 - loss: 0.0362 - val_accuracy: 0.7989 - val_loss: 0.0339
# Epoch 94/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7821 - loss: 0.0364 - val_accuracy: 0.8002 - val_loss: 0.0335
# Epoch 95/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7827 - loss: 0.0362 - val_accuracy: 0.7994 - val_loss: 0.0337
# Epoch 96/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7831 - loss: 0.0363 - val_accuracy: 0.7994 - val_loss: 0.0340
# Epoch 97/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7817 - loss: 0.0360 - val_accuracy: 0.8005 - val_loss: 0.0336
# Epoch 98/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7829 - loss: 0.0363 - val_accuracy: 0.7972 - val_loss: 0.0338
# Epoch 99/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7829 - loss: 0.0363 - val_accuracy: 0.7994 - val_loss: 0.0335
# Epoch 100/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7822 - loss: 0.0362 - val_accuracy: 0.8001 - val_loss: 0.0336
# Epoch 101/1000
# 2123/2123 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7827 - loss: 0.0360 - val_accuracy: 0.7987 - val_loss: 0.0339
# Epoch 101: early stopping

# %% [markdown]
# ### MOdel evaluation

# %%
model_history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
#evaluating the model
def focal_loss(gamma=2., alpha=.25):

    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.int32)
        num_classes = K.int_shape(y_pred)[-1]
        y_true_one_hot = tf.one_hot(y_true, depth=num_classes)
        y_pred = K.clip(y_pred, K.epsilon(), 1.0 - K.epsilon())
        cross_entropy = -y_true_one_hot * K.log(y_pred)
        loss_weight = y_true_one_hot * K.pow(1 - y_pred, gamma)
        if alpha is not None:
            alpha_factor = K.ones_like(y_true_one_hot) * alpha
            loss_weight *= alpha_factor
        loss = loss_weight * cross_entropy
        return K.sum(loss, axis=-1)
    return focal_loss_fixed

print("Evaluating the model on the test set...")

loss, accuracy = classifier.evaluate(x_test_processed, y_test_encoded)

print(f"\nFinal Test Loss: {loss:.4f}")
print(f"Final Test Accuracy: {accuracy:.4f}")
# Out:
# Evaluating the model on the test set...
# 793/793 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7959 - loss: 0.0339
#
# Final Test Loss: 0.0340
# Final Test Accuracy: 0.7957

# %% [markdown]
# #### Confusion matrix

# %%
#using confusion matrix to get more accurate model performance

def plot_confusion_matrix(classifier, x_test, y_test_encoded, class_names):
  
    y_pred_probs = classifier.predict(x_test_processed)
    y_pred_classes = np.argmax(y_pred_probs, axis=1)
    
    y_true_classes = y_test_encoded
    
    cm = confusion_matrix(y_true_classes, y_pred_classes)
    
    plt.figure(figsize=(8, 6))
    sns.heatmap(
        cm, 
        annot=True, 
        fmt="d", 
        cmap="Blues", 
        xticklabels=class_names, 
        yticklabels=class_names
    )
    plt.title("Confusion Matrix for Failure Prediction")
    plt.ylabel("Actual Label")
    plt.xlabel("Predicted Label")
    plt.show()

if __name__ == "__main__":
    
    CLASS_NAMES = ['Electrical Failure', 'Mechanical Failure', 'Sensor Malfunction'] 
    
plot_confusion_matrix(classifier, x_test_processed, y_test_encoded, CLASS_NAMES)
# Out:
# 793/793 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
